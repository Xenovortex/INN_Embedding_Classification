# %% [markdown]
# # Import Packages

# %%
from experiment import inn_experiment as ie
from functionalities import gpu
import warnings
warnings.filterwarnings(action='once')

# %% [markdown]
# # Set Training Parameters

# %%
num_epoch = 40
batch_size = 1024
lr_init = 5e-4
mu_init = 110.
beta = 5 #5.0
milestones = [20, 30, 40]
modelname = "cifar_feature_17layers_beta5"
number_dev = 4
use_vgg = True
num_workers = 8
dataset = "cifar"
interval_log = 1
interval_checkpoint = 10
interval_figure = 20

device = gpu.get_device(number_dev)
print(device)
# Out:
# cuda

# %% [markdown]
# # Training

# %%
inn_exp = ie.inn_experiment(num_epoch, batch_size, milestones, modelname, device, lr_init, mu_init, beta, use_vgg=use_vgg, interval_log=interval_log, interval_checkpoint=interval_checkpoint, interval_figure=interval_figure)
inn_exp.get_dataset(dataset, num_workers=num_workers)
inn_exp.train()
#inn_exp.load_inn()
inn_exp.print_accuracy()
inn_exp.plot_loss()
inn_exp.outlier_histogram()
inn_exp.calibration_curve()
# Out:
# Device used for further computation is: cuda
#
# Loading Dataset: cifar
# Files already downloaded and verified
# Files already downloaded and verified
# Node 'fc1' takes the following inputs:
# 	 Output #0 of node 'input' with dims (4096,)
#
# Node 'fc2' takes the following inputs:
# 	 Output #0 of node 'fc1' with dims (4096,)
#
# Node 'fc3' takes the following inputs:
# 	 Output #0 of node 'fc2' with dims (4096,)
#
# Node 'output' takes the following inputs:
# 	 Output #0 of node 'fc3' with dims (4096,)
#
# Finished!
#
# --------------------------------------------------------------------------------
#
# Epoch: 1
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             0.2      0000/0040       26.49988       26.73148      948.61260       10.48887       10.52343      141.54429        0.67057       98.57603
# Create Plots:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# --------------------------------------------------------------------------------
#
# Epoch: 2
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             0.5      0001/0040        7.40957        7.43392       99.76108        5.17292        5.18401       45.40477        0.76649       94.16144
#
# --------------------------------------------------------------------------------
#
# Epoch: 3
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             0.7      0002/0040        4.80842        4.82284       59.03771        4.11987        4.12935       38.84352        0.76899       90.00568
#
# --------------------------------------------------------------------------------
#
# Epoch: 4
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             0.9      0003/0040        4.12082        4.13209       46.17521        3.75611        3.76832       50.01184        0.74208       85.91362
#
# --------------------------------------------------------------------------------
#
# Epoch: 5
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             1.1      0004/0040        3.92183        3.93212       42.13599        3.75049        3.77766      111.29047        0.68576       81.45929
#
# --------------------------------------------------------------------------------
#
# Epoch: 6
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             1.4      0005/0040        3.77981        3.78854       35.75478        3.55614        3.56623       41.36372        0.75228       78.50691
#
# --------------------------------------------------------------------------------
#
# Epoch: 7
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             1.6      0006/0040        3.63294        3.63933       26.15923        3.46904        3.48243       54.82364        0.72613       74.73645
#
# --------------------------------------------------------------------------------
#
# Epoch: 8
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             1.8      0007/0040        3.60783        3.61341       22.87809        3.51996        3.53013       41.65077        0.77496       72.02285
#
# --------------------------------------------------------------------------------
#
# Epoch: 9
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             2.0      0008/0040        3.65780        3.66230       18.42972        3.53292        3.54201       37.21633        0.77691       71.33684
#
# --------------------------------------------------------------------------------
#
# Epoch: 10
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             2.2      0009/0040        3.69192        3.69597       16.56177        3.55395        3.56456       43.47535        0.76975       69.43105
#
# --------------------------------------------------------------------------------
#
# Epoch: 11
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             2.4      0010/0040        3.77319        3.77657       13.87556        3.66331        3.67028       28.55898        0.82270       69.83213
# Model saved!
#
# --------------------------------------------------------------------------------
#
# Epoch: 12
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             2.7      0011/0040        3.87915        3.88202       11.76276        3.76819        3.77933       45.64516        0.78299       71.05100
#
# --------------------------------------------------------------------------------
#
# Epoch: 13
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             3.0      0012/0040        4.05394        4.05661       10.92191        3.85798        3.86623       33.76709        0.83388       72.19305
#
# --------------------------------------------------------------------------------
#
# Epoch: 14
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             3.2      0013/0040        4.14439        4.14656        8.88207        3.98165        3.99425       51.60867        0.79210       75.10710
#
# --------------------------------------------------------------------------------
#
# Epoch: 15
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             3.4      0014/0040        4.30336        4.30539        8.31987        4.19759        4.20822       43.53139        0.83366       77.47772
#
# --------------------------------------------------------------------------------
#
# Epoch: 16
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             3.6      0015/0040        4.46751        4.46933        7.47534        4.50851        4.52040       48.69809        0.82856       80.42110
#
# --------------------------------------------------------------------------------
#
# Epoch: 17
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             3.8      0016/0040        4.67449        4.67627        7.29120        4.51038        4.52325       52.70047        0.82552       83.61995
#
# --------------------------------------------------------------------------------
#
# Epoch: 18
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             4.0      0017/0040        4.75322        4.75493        6.97692        4.59007        4.60281       52.18154        0.83843       86.26881
#
# --------------------------------------------------------------------------------
#
# Epoch: 19
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             4.3      0018/0040        4.91164        4.91331        6.86408        4.89989        4.91370       56.57430        0.84288       89.80934
#
# --------------------------------------------------------------------------------
#
# Epoch: 20
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             4.5      0019/0040        5.17624        5.17764        5.74559        4.90019        4.91833       74.28364        0.81890       93.12260
#
# --------------------------------------------------------------------------------
#
# Epoch: 21
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             4.7      0020/0040        5.12955        5.12989        1.38644        4.76632        4.77879       51.05447        0.84950       92.66902
# Model saved!
# Create Plots:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# --------------------------------------------------------------------------------
#
# Epoch: 22
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             5.0      0021/0040        4.98940        4.98920       -0.81683        4.69070        4.70244       48.07012        0.85341       92.42559
#
# --------------------------------------------------------------------------------
#
# Epoch: 23
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             5.3      0022/0040        4.91704        4.91675       -1.18700        4.61630        4.62762       46.39143        0.85655       92.28305
#
# --------------------------------------------------------------------------------
#
# Epoch: 24
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             5.5      0023/0040        4.84148        4.84113       -1.42875        4.55982        4.57121       46.65907        0.85276       92.18661
#
# --------------------------------------------------------------------------------
#
# Epoch: 25
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             5.7      0024/0040        4.74878        4.74840       -1.54135        4.45239        4.46319       44.23343        0.85438       92.08563
#
# --------------------------------------------------------------------------------
#
# Epoch: 26
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             5.9      0025/0040        4.66719        4.66677       -1.74717        4.40268        4.41340       43.91571        0.85232       92.03049
#
# --------------------------------------------------------------------------------
#
# Epoch: 27
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             6.1      0026/0040        4.62728        4.62685       -1.77594        4.36589        4.37629       42.58859        0.85525       92.04253
#
# --------------------------------------------------------------------------------
#
# Epoch: 28
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             6.4      0027/0040        4.53210        4.53165       -1.81927        4.26179        4.27202       41.90930        0.85406       91.87615
#
# --------------------------------------------------------------------------------
#
# Epoch: 29
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             6.6      0028/0040        4.45109        4.45066       -1.78552        4.21027        4.22030       41.07927        0.85243       91.87883
#
# --------------------------------------------------------------------------------
#
# Epoch: 30
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             6.8      0029/0040        4.40316        4.40270       -1.86533        4.16687        4.17668       40.21162        0.85211       91.77541
#
# --------------------------------------------------------------------------------
#
# Epoch: 31
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             7.0      0030/0040        4.36939        4.36891       -1.95704        4.15945        4.16905       39.30090        0.85297       91.76269
# Model saved!
#
# --------------------------------------------------------------------------------
#
# Epoch: 32
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             7.3      0031/0040        4.35709        4.35661       -1.95775        4.14392        4.15348       39.15231        0.85135       91.74252
#
# --------------------------------------------------------------------------------
#
# Epoch: 33
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             7.5      0032/0040        4.33963        4.33914       -1.99759        4.13121        4.14073       38.97410        0.85276       91.71595
#
# --------------------------------------------------------------------------------
#
# Epoch: 34
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             7.7      0033/0040        4.32757        4.32708       -2.00160        4.11785        4.12731       38.74029        0.85221       91.71207
#
# --------------------------------------------------------------------------------
#
# Epoch: 35
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             8.0      0034/0040        4.31357        4.31306       -2.09904        4.10525        4.11465       38.52233        0.85341       91.70399
#
# --------------------------------------------------------------------------------
#
# Epoch: 36
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             8.2      0035/0040        4.29765        4.29716       -2.01978        4.09401        4.10336       38.30233        0.85362       91.68231
#
# --------------------------------------------------------------------------------
#
# Epoch: 37
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             8.4      0036/0040        4.28313        4.28262       -2.05761        4.07824        4.08755       38.13771        0.85308       91.66722
#
# --------------------------------------------------------------------------------
#
# Epoch: 38
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             8.6      0037/0040        4.26867        4.26816       -2.06272        4.06449        4.07379       38.07806        0.85211       91.62827
#
# --------------------------------------------------------------------------------
#
# Epoch: 39
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             8.8      0038/0040        4.25555        4.25504       -2.10512        4.05397        4.06323       37.95360        0.85428       91.60423
#
# --------------------------------------------------------------------------------
#
# Epoch: 40
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             9.1      0039/0040        4.24486        4.24435       -2.10009        4.04875        4.05801       37.92701        0.85341       91.58279
#
# ################################################################################
# ################################################################################
#
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# Final Test Accuracy: 0.8534071180555556
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# Final Test Accuracy: 0.8534071180555556
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=49), HTML(value='')))
# /net/hcihome/storage/yveniche/INN_Embedding_Classification/experiment/inn_experiment.py:515: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
#   pred_bins = np.quantile(pred, np.linspace(0., 1., n_bins))
# 293

# %%
inn_exp.outlier_histogram(val_range=[2, 6.5])
# Out:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=49), HTML(value='')))
# val_range: [1.865, 6.63905]
