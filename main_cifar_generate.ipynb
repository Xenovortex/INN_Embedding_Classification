# %% [markdown]
# # Import Packages

# %%
from experiment import inn_experiment as ie
from functionalities import gpu
import warnings
warnings.filterwarnings(action='once')

# %% [markdown]
# # Set Training Parameters

# %%
num_epoch = 40
batch_size = 1024
lr_init = 5e-4
mu_init = 110.
beta = 5 #5.0
milestones = [20, 30, 40]
modelname = "cifar_generate_beta5"
number_dev = 3
use_vgg = False
num_workers = 8
dataset = "cifar"
interval_log = 1
interval_checkpoint = 10
interval_figure = 20

device = gpu.get_device(number_dev)
print(device)
# Out:
# cuda

# %% [markdown]
# # Training

# %%
inn_exp = ie.inn_experiment(num_epoch, batch_size, milestones, modelname, device, lr_init, mu_init, beta, use_vgg=use_vgg, interval_log=interval_log, interval_checkpoint=interval_checkpoint, interval_figure=interval_figure)
inn_exp.get_dataset(dataset, num_workers=num_workers)
inn_exp.train()
inn_exp.print_accuracy()
inn_exp.plot_loss()
inn_exp.outlier_histogram()
inn_exp.calibration_curve()
# Out:
# Device used for further computation is: cuda
#
# Loading Dataset: cifar
# Files already downloaded and verified
# Files already downloaded and verified
# (3, 32, 32)
# Node 'reshape' takes the following inputs:
# 	 Output #0 of node 'input' with dims (3, 32, 32)
#
# Node 'haar_down_1' takes the following inputs:
# 	 Output #0 of node 'reshape' with dims (3, 32, 32)
#
# Node 'CB CONV_0_0' takes the following inputs:
# 	 Output #0 of node 'haar_down_1' with dims (12, 16, 16)
#
# Node 'CB CONV_0_1' takes the following inputs:
# 	 Output #0 of node 'CB CONV_0_0' with dims (12, 16, 16)
#
# Node '96f208' takes the following inputs:
# 	 Output #0 of node 'CB CONV_0_1' with dims (12, 16, 16)
#
# Node 'haar_down_2' takes the following inputs:
# 	 Output #0 of node '96f208' with dims (12, 16, 16)
#
# Node 'CB CONV_1_0' takes the following inputs:
# 	 Output #0 of node 'haar_down_2' with dims (48, 8, 8)
#
# Node 'CB CONV_1_1' takes the following inputs:
# 	 Output #0 of node 'CB CONV_1_0' with dims (48, 8, 8)
#
# Node '96f278' takes the following inputs:
# 	 Output #0 of node 'CB CONV_1_1' with dims (48, 8, 8)
#
# Node 'flatten' takes the following inputs:
# 	 Output #0 of node '96f278' with dims (48, 8, 8)
#
# Node 'CB FC_0' takes the following inputs:
# 	 Output #0 of node 'flatten' with dims (3072,)
#
# Node 'CB FC_1' takes the following inputs:
# 	 Output #0 of node 'CB FC_0' with dims (3072,)
#
# Node '96f588' takes the following inputs:
# 	 Output #0 of node 'CB FC_1' with dims (3072,)
#
# Node 'CB FC_2' takes the following inputs:
# 	 Output #0 of node '96f588' with dims (3072,)
#
# Node 'CB FC_3' takes the following inputs:
# 	 Output #0 of node 'CB FC_2' with dims (3072,)
#
# Node '96f6d8' takes the following inputs:
# 	 Output #0 of node 'CB FC_3' with dims (3072,)
#
# Node 'CB FC_4' takes the following inputs:
# 	 Output #0 of node '96f6d8' with dims (3072,)
#
# Node 'CB FC_5' takes the following inputs:
# 	 Output #0 of node 'CB FC_4' with dims (3072,)
#
# Node '96f828' takes the following inputs:
# 	 Output #0 of node 'CB FC_5' with dims (3072,)
#
# Node 'CB FC_6' takes the following inputs:
# 	 Output #0 of node '96f828' with dims (3072,)
#
# Node 'CB FC_7' takes the following inputs:
# 	 Output #0 of node 'CB FC_6' with dims (3072,)
#
# Node '96f978' takes the following inputs:
# 	 Output #0 of node 'CB FC_7' with dims (3072,)
#
# Node 'CB FC_8' takes the following inputs:
# 	 Output #0 of node '96f978' with dims (3072,)
#
# Node 'CB FC_9' takes the following inputs:
# 	 Output #0 of node 'CB FC_8' with dims (3072,)
#
# Node '96fac8' takes the following inputs:
# 	 Output #0 of node 'CB FC_9' with dims (3072,)
#
# Node 'CB FC_10' takes the following inputs:
# 	 Output #0 of node '96fac8' with dims (3072,)
#
# Node 'CB FC_11' takes the following inputs:
# 	 Output #0 of node 'CB FC_10' with dims (3072,)
#
# Node '96fba8' takes the following inputs:
# 	 Output #0 of node 'CB FC_11' with dims (3072,)
#
# Node 'output' takes the following inputs:
# 	 Output #0 of node '96fba8' with dims (3072,)
#
# Finished!
#
# --------------------------------------------------------------------------------
#
# Epoch: 1
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             0.4      0000/0040        2.10872        2.15985      157.06823        1.64265        1.67013       84.43419        0.20768       93.69285
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Create Plots:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# --------------------------------------------------------------------------------
#
# Epoch: 2
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             0.9      0001/0040        1.20118        1.23248       96.15828        0.91575        0.95465      119.49463        0.17578       86.53507
#
# --------------------------------------------------------------------------------
#
# Epoch: 3
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             1.2      0002/0040        0.58329        0.60874       78.19433        0.32573        0.36002      105.33087        0.23611       79.21841
#
# --------------------------------------------------------------------------------
#
# Epoch: 4
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             1.6      0003/0040        0.13390        0.15616       68.36032       -0.03818       -0.00928       88.80613        0.29112       71.62662
#
# --------------------------------------------------------------------------------
#
# Epoch: 5
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             2.0      0004/0040       -0.18916       -0.17061       56.97707       -0.34095       -0.32598       45.98593        0.30154       64.12104
#
# --------------------------------------------------------------------------------
#
# Epoch: 6
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             2.3      0005/0040       -0.45328       -0.43849       45.45203       -0.57018       -0.55590       43.87024        0.34017       56.51120
#
# --------------------------------------------------------------------------------
#
# Epoch: 7
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             2.7      0006/0040       -0.68213       -0.66981       37.84139       -0.79663       -0.78540       34.52278        0.41753       48.58407
#
# --------------------------------------------------------------------------------
#
# Epoch: 8
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             3.1      0007/0040       -0.87808       -0.86817       30.45962       -0.98797       -0.98008       24.23396        0.37684       40.31203
#
# --------------------------------------------------------------------------------
#
# Epoch: 9
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             3.4      0008/0040       -1.08499       -1.07739       23.35102       -1.20949       -1.20506       13.58885        0.45877       31.48464
#
# --------------------------------------------------------------------------------
#
# Epoch: 10
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             3.8      0009/0040       -1.27246       -1.26717       16.25652       -1.32894       -1.32393       15.40201        0.40093       23.11531
#
# --------------------------------------------------------------------------------
#
# Epoch: 11
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             4.2      0010/0040       -1.40349       -1.39984       11.22374       -1.48426       -1.48068       10.99814        0.41070       15.95926
# Model saved!
#
# --------------------------------------------------------------------------------
#
# Epoch: 12
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             4.8      0011/0040       -1.50128       -1.49867        7.99243       -1.55601       -1.55462        4.26066        0.52257       10.25049
#
# --------------------------------------------------------------------------------
#
# Epoch: 13
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             5.2      0012/0040       -1.56104       -1.55945        4.89608       -1.58045       -1.57917        3.93706        0.44412        8.67834
#
# --------------------------------------------------------------------------------
#
# Epoch: 14
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             5.6      0013/0040       -1.57433       -1.57248        5.68224       -1.58786       -1.58690        2.94709        0.47146        7.38601
#
# --------------------------------------------------------------------------------
#
# Epoch: 15
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             6.0      0014/0040       -1.58213       -1.58092        3.73596       -1.58196       -1.58042        4.74328        0.47266        7.46168
#
# --------------------------------------------------------------------------------
#
# Epoch: 16
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             6.4      0015/0040       -1.59109       -1.58965        4.40885       -1.62559       -1.62475        2.58564        0.47059        6.77295
#
# --------------------------------------------------------------------------------
#
# Epoch: 17
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             6.8      0016/0040       -1.61991       -1.61860        4.03034       -1.61245       -1.61178        2.04789        0.51302        7.13573
#
# --------------------------------------------------------------------------------
#
# Epoch: 18
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             7.2      0017/0040       -1.62558       -1.62430        3.91792       -1.64005       -1.63850        4.75701        0.49967        7.44954
#
# --------------------------------------------------------------------------------
#
# Epoch: 19
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             7.6      0018/0040       -1.63694       -1.63579        3.50606       -1.64992       -1.64917        2.32453        0.51487        7.10634
#
# --------------------------------------------------------------------------------
#
# Epoch: 20
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             8.0      0019/0040       -1.65261       -1.65144        3.61100       -1.66726       -1.66565        4.94810        0.53114        7.58386
#
# --------------------------------------------------------------------------------
#
# Epoch: 21
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             8.4      0020/0040       -1.64453       -1.64470       -0.54364       -1.65187       -1.65225       -1.15105        0.62489        4.92861
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Model saved!
# Create Plots:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# --------------------------------------------------------------------------------
#
# Epoch: 22
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             9.1      0021/0040       -1.66751       -1.66793       -1.31037       -1.68986       -1.69026       -1.24621        0.64052        4.83497
#
# --------------------------------------------------------------------------------
#
# Epoch: 23
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             9.4      0022/0040       -1.70669       -1.70713       -1.36293       -1.72977       -1.73019       -1.29063        0.65853        5.10787
#
# --------------------------------------------------------------------------------
#
# Epoch: 24
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#             9.8      0023/0040       -1.74704       -1.74749       -1.37577       -1.77247       -1.77289       -1.28537        0.65647        5.30893
#
# --------------------------------------------------------------------------------
#
# Epoch: 25
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            10.3      0024/0040       -1.79120       -1.79165       -1.38590       -1.81549       -1.81591       -1.27181        0.65451        5.45459
#
# --------------------------------------------------------------------------------
#
# Epoch: 26
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            10.7      0025/0040       -1.83588       -1.83633       -1.38414       -1.86281       -1.86323       -1.27764        0.65343        5.61064
#
# --------------------------------------------------------------------------------
#
# Epoch: 27
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            11.1      0026/0040       -1.88346       -1.88392       -1.38993       -1.90793       -1.90836       -1.31881        0.67014        5.67727
#
# --------------------------------------------------------------------------------
#
# Epoch: 28
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            11.5      0027/0040       -1.92931       -1.92976       -1.39225       -1.95446       -1.95487       -1.27588        0.66070        5.78881
#
# --------------------------------------------------------------------------------
#
# Epoch: 29
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            11.9      0028/0040       -1.97611       -1.97657       -1.40150       -2.00092       -2.00132       -1.21597        0.63759        5.91819
#
# --------------------------------------------------------------------------------
#
# Epoch: 30
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            12.3      0029/0040       -2.02378       -2.02424       -1.40286       -2.04931       -2.04971       -1.23437        0.64746        6.01187
#
# --------------------------------------------------------------------------------
#
# Epoch: 31
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            12.7      0030/0040       -2.04958       -2.05009       -1.56329       -2.05857       -2.05901       -1.35746        0.67502        5.99384
# Model saved!
#
# --------------------------------------------------------------------------------
#
# Epoch: 32
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            13.3      0031/0040       -2.06146       -2.06198       -1.58586       -2.07222       -2.07266       -1.36070        0.67773        6.05156
#
# --------------------------------------------------------------------------------
#
# Epoch: 33
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            13.7      0032/0040       -2.07652       -2.07704       -1.59384       -2.08826       -2.08871       -1.36031        0.67871        6.12876
#
# --------------------------------------------------------------------------------
#
# Epoch: 34
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            14.1      0033/0040       -2.09310       -2.09362       -1.59873       -2.10578       -2.10622       -1.35829        0.67860        6.20733
#
# --------------------------------------------------------------------------------
#
# Epoch: 35
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            14.4      0034/0040       -2.11124       -2.11177       -1.60783       -2.12446       -2.12490       -1.35583        0.67611        6.29105
#
# --------------------------------------------------------------------------------
#
# Epoch: 36
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            14.8      0035/0040       -2.13050       -2.13103       -1.60798       -2.14431       -2.14475       -1.35395        0.67893        6.37471
#
# --------------------------------------------------------------------------------
#
# Epoch: 37
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            15.2      0036/0040       -2.15066       -2.15119       -1.61401       -2.16469       -2.16513       -1.34992        0.67795        6.44616
#
# --------------------------------------------------------------------------------
#
# Epoch: 38
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            15.5      0037/0040       -2.17100       -2.17153       -1.61607       -2.18499       -2.18543       -1.34785        0.67632        6.51744
#
# --------------------------------------------------------------------------------
#
# Epoch: 39
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            15.9      0038/0040       -2.19106       -2.19159       -1.62210       -2.20511       -2.20555       -1.34449        0.67719        6.59169
#
# --------------------------------------------------------------------------------
#
# Epoch: 40
# Training:
# HBox(children=(IntProgress(value=0, max=48), HTML(value='')))
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
#            16.3      0039/0040       -2.21075       -2.21128       -1.62227       -2.22444       -2.22487       -1.33959        0.67480        6.65855
#
# ################################################################################
# ################################################################################
#
# Evaluating:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Final Test Accuracy: 0.6748046875
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# Final Test Accuracy: 0.6748046875
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=49), HTML(value='')))
# /net/hcihome/storage/yveniche/INN_Embedding_Classification/experiment/inn_experiment.py:515: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
#   pred_bins = np.quantile(pred, np.linspace(0., 1., n_bins))
# /net/hcihome/storage/yveniche/INN_Embedding_Classification/experiment/inn_experiment.py:527: RuntimeWarning: divide by zero encountered in true_divide
#   poisson_err = q * np.sqrt(1 / hist_correct + 1 / (hist_wrong + hist_correct))
# /net/hcihome/storage/yveniche/INN_Embedding_Classification/experiment/inn_experiment.py:527: RuntimeWarning: invalid value encountered in multiply
#   poisson_err = q * np.sqrt(1 / hist_correct + 1 / (hist_wrong + hist_correct))
# 86813

# %%
inn_exp.outlier_histogram(val_range=[-2.5, -1.8])
# Out:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=49), HTML(value='')))
# val_range: [-2.521, -1.77837]
